# %%
import pandas as pd
import requests
import time
import re
from collections import Counter
import google.generativeai as genai
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse

# %%
df = pd.read_csv("Links_for_all_conferences.csv")
df
# Out:
#                                                  Title  \
# 0         2025 PCI SSC North America Community Meeting
# 1                2025 PCI SSC Europe Community Meeting
# 2          2025 PCI SSC Asia-Pacific Community Meeting
# 3                                  RSA Conference 2025
# 4                        Innovate Cybersecurity Summit
# ..                                                 ...
# 232              Virginia HIMSS Annual Fall Conference
# 233                                      GNUHealth Con
# 234                                AIMed Global Summit
# 235  International Conference on Nursing and Health...
# 236                           Healthcare Summit London
#
#                                                   Link                Type
# 0            https://events.pcisecuritystandards.org/#       CyberSecurity
# 1            https://events.pcisecuritystandards.org/#       CyberSecurity
# 2            https://events.pcisecuritystandards.org/#       CyberSecurity
# 3                    https://www.rsaconference.com/usa       CyberSecurity
# 4             https://innovatecybersecuritysummit.com/       CyberSecurity
# ..                                                 ...                 ...
# 232                            https://www.vahimss.org  Health Informatics
# 233                       https://www.gnuhealthcon.org  Health Informatics
# 234                               https://aimed.events  Health Informatics
# 235                  https://www.nursingconference.com  Health Informatics
# 236  https://thenueconomy.com/top-global-health-tec...  Health Informatics
#
# [237 rows x 3 columns]

# %%
conferences = df

# %%
conferences.Title = conferences.Title.astype(str)

# %%
#Let the scraping begin

# %%
# API Keys - Replace with your actual keys
GEMINI_API_KEY = ""
GOOGLE_SEARCH_API_KEY = ""
SEARCH_ENGINE_ID = ""

# %%
def google_search(query, api_key, search_engine_id, num_results=3):
    """Search Google using Custom Search API"""
    url = "https://www.googleapis.com/customsearch/v1"
    params = {
        'key': api_key,
        'cx': search_engine_id,
        'q': query,
        'num': num_results
    }
    
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        return response.json()
    except Exception as e:
        print(f"Error searching for {query}: {e}")
        return None

# %%
def extract_keywords_with_gemini(text):
    """Extract relevant keywords from text using Gemini API"""
    import google.generativeai as genai
    
    # Configure Gemini API
    genai.configure(api_key=GEMINI_API_KEY)
    model = genai.GenerativeModel('gemini-2.5-pro-preview-05-06')
    
    # Create prompt for keyword extraction
    prompt = f"""
Analyze the following text and extract the 10 most relevant keywords and topics.

Focus on:
- Technical or specialized subject areas discussed
- Industry sectors or application domains referenced
- Major themes, challenges, or areas of focus
- Important methods, tools, or approaches mentioned

Return only a concise, comma-separated list of 5-10 highly relevant keywords or topics that best summarize the content. Do not include explanations.

Text to analyze:
{text[:2000]}  # Limit text length for API efficiency
"""

    
    try:
        response = model.generate_content(prompt)
        keywords_text = response.text.strip()
        
        # Clean and format keywords
        keywords = [k.strip().lower() for k in keywords_text.split(',') if k.strip()]
        return keywords[:10]  # Limit to 10 keywords max
        
    except Exception as e:
        print(f"Error with Gemini API: {e}")
        # Fallback to simple keyword extraction
        return extract_keywords_simple(text)

# %%
def analyze_conference_keywords(df):
    """Analyze each conference and extract keywords"""
    keywords_list = []
    
    for index, row in df.iterrows():
        print(f"Processing {index + 1}/{len(df)}: {row['Title']}")
        
        # Search for conference information
        search_query = f"{row['Title']} conference agenda topics"
        search_results = google_search(search_query, GOOGLE_SEARCH_API_KEY, SEARCH_ENGINE_ID)
        
        keywords = []
        if search_results and 'items' in search_results:
            # Extract text from search results
            all_text = ""
            for item in search_results['items']:
                all_text += item.get('title', '') + " " + item.get('snippet', '') + " "
            
            # Extract keywords from the text using Gemini
            keywords = extract_keywords_with_gemini(all_text)
        
        # If no keywords found, try searching with just the title
        if not keywords:
            search_query = f"{row['Title']}"
            search_results = google_search(search_query, GOOGLE_SEARCH_API_KEY, SEARCH_ENGINE_ID)
            
            if search_results and 'items' in search_results:
                all_text = ""
                for item in search_results['items']:
                    all_text += item.get('title', '') + " " + item.get('snippet', '') + " "
                keywords = extract_keywords_with_gemini(all_text)
        
        # Add conference type as keyword if no other keywords found
        if not keywords and 'Type' in row:
            keywords = [row['Type'].lower()]
        
        keywords_list.append(', '.join(keywords) if keywords else 'No keywords found')
        
        # Rate limiting to avoid API quota issues
        time.sleep(1)
    
    return keywords_list

# %%
print("\nStarting keyword extraction...")
keywords = analyze_conference_keywords(df)
df['Keywords'] = keywords
# Out:
# Starting keyword extraction...
# Processing 1/237: 2025 PCI SSC North America Community Meeting
# Processing 2/237: 2025 PCI SSC Europe Community Meeting
# Processing 3/237: 2025 PCI SSC Asia-Pacific Community Meeting
# Processing 4/237: RSA Conference 2025
# Processing 5/237: Innovate Cybersecurity Summit
# Processing 6/237: SAINTCON
# Processing 7/237: Cloud & Cyber Security Expo
# Processing 8/237: HIMSS
# Processing 9/237: HIMSS Europe
# Processing 10/237: WiCyS
# Processing 11/237: Gartner Security & Risk Management Summit
# Processing 12/237: ISACA North America Conference
# Processing 13/237: GRC Conference 2025
# Processing 14/237: ISACA Europe Conference
# Processing 15/237: The Diana Initiative
# Processing 16/237: Apres-Cyber Slopes Summit
# Processing 17/237: DEF CON
# Processing 18/237: Association of Payment Professionals
# Processing 19/237: Black Hat
# Processing 20/237: Zero Trust World (ThreatLocker)
# Processing 21/237: ICCWS
# Processing 22/237: HACKMIAMI
# Processing 23/237: Techno Security & Digital Forensics Conference
# Processing 24/237: BSides
# Processing 25/237: Aspen Cyber Summit
# Processing 26/237: AISTATS 2025
# Processing 27/237: CVPR 2025
# Processing 28/237: NAACL 2025
# Processing 29/237: ICLR 2025
# Processing 30/237: LoG 2024
# Processing 31/237: ECIR 2025
# Processing 32/237: WACV 2025
# Processing 33/237: AAMAS 2025
# Processing 34/237: CHI 2025
# Processing 35/237: COLING 2025
# Processing 36/237: WSDM 2025
# Processing 37/237: Iberamia 2024
# Processing 38/237: NeurIPS [Dataset and Benchmarks Track] 2024
# Processing 39/237: ICRA 2025
# Processing 40/237: WACV 2025
# Processing 41/237: AAAI 2025
# Processing 42/237: BMVC 2024
# Processing 43/237: ICASSP 2025
# Processing 44/237: KIL 2024
# Processing 45/237: ISMIR 2024
# Processing 46/237: SPAICE 2024
# Processing 47/237: EMNLP 2024
# Processing 48/237: CIKM 2024
# Processing 49/237: SIGGRAPH Asia 2024
# Processing 50/237: NeurIPS 2024
# Processing 51/237: ECML PKDD 2024
# Processing 52/237: AABI 2024
# Processing 53/237: CoRL 2024
# Processing 54/237: MM 2024
# Processing 55/237: ACL 2024
# Processing 56/237: IROS 2024
# Processing 57/237: KR 2024
# Processing 58/237: AAAI 2024 Spring Symposium on Clinical Foundation Models 2024
# Processing 59/237: AAAI 2024 Spring Symposium on User-Aligned Assessment of Adaptive AI Systems 2024
# Processing 60/237: SIGGRAPH 2024
# Processing 61/237: UAI 2024
# Processing 62/237: CoLLAs 2024
# Processing 63/237: ECAI 2024
# Processing 64/237: RLC 2024
# Processing 65/237: KDD 2024
# Processing 66/237: RSS 2024
# Processing 67/237: ICML 2024
# Processing 68/237: MICCAI 2024
# Processing 69/237: SIGIR 2024
# Processing 70/237: COLM 2024
# Processing 71/237: IJCAI 2024
# Processing 72/237: CHIL 2024
# Processing 73/237: SaTML 2024
# Processing 74/237: ECCV 2024
# Processing 75/237: CLeaR 2024
# Processing 76/237: ICPRAI 2024
# Processing 77/237: ICAPS 2024
# Processing 78/237: NAACL 2024
# Processing 79/237: CSCW 2024
# Processing 80/237: IUI 2024
# Processing 81/237: AISTATS 2024
# Processing 82/237: ICASSP 2024
# Processing 83/237: HRI 2024
# Processing 84/237: WACV 2024
# Processing 85/237: EACL 2024
# Processing 86/237: 3DV 2024
# Processing 87/237: ICLR 2024
# Processing 88/237: CVPR 2024
# Processing 89/237: ICRA 2024
# Processing 90/237: CoNLL 2023
# Processing 91/237: AAMAS 2024
# Processing 92/237: AAAI 2024
# Processing 93/237: ECIR 2024
# Processing 94/237: CHI 2024
# Processing 95/237: LREC-COLING 2024
# Processing 96/237: IJCNLP-AACL 2023
# Processing 97/237: RecSys 2023
# Processing 98/237: ACML 2023
# Processing 99/237: SIGIR-AP 2023
# Processing 100/237: EMNLP 2023
# Processing 101/237: *SEM 2023
# Processing 102/237: SIGGRAPH Asia 2023
# Processing 103/237: CoRL 2023
# Processing 104/237: ECAI 2023
# Processing 105/237: MM 2023
# Processing 106/237: RO-MAN 2023
# Processing 107/237: NeurIPS 2023
# Processing 108/237: AutoML-Conf 2023
# Processing 109/237: CoLLAs 2023
# Processing 110/237: UAI 2023
# Processing 111/237: RSS 2023
# Processing 112/237: IJCAI 2023
# Processing 113/237: ICML 2023
# Processing 114/237: SIGIR 2023
# Processing 115/237: IROS 2023
# Processing 116/237: KR 2023
# Processing 117/237: ICAPS 2023
# Processing 118/237: ACL 2023
# Processing 119/237: EACL 2023
# Processing 120/237: PAKDD 2023
# Processing 121/237: AISTATS 2023
# Processing 122/237: ICLR 2023
# Processing 123/237: ACML 2022
# Processing 124/237: AAAI 2023
# Processing 125/237: ICDM 2022
# Processing 126/237: EMNLP 2022
# Processing 127/237: WSDM 2023
# Processing 128/237: MM 2022
# Processing 129/237: ICMI 2022
# Processing 130/237: CIKM 2022
# Processing 131/237: COLING 2022
# Processing 132/237: NeurIPS 2022
# Processing 133/237: ISMIR 2022
# Processing 134/237: AACL-IJCNLP 2022
# Processing 135/237: CoRL 2022
# Processing 136/237: ALT 2020
# Processing 137/237: HRI 2020
# Processing 138/237: ICMR 2020
# Processing 139/237: COLT 2020
# Processing 140/237: ICCC 2020
# Processing 141/237: ISMIR 2020
# Processing 142/237: AACL-IJCNLP 2020
# Processing 143/237: ACCV 2020
# Processing 144/237: ICPR 2020
# Processing 145/237: CoNLL 2020
# Processing 146/237: 3DV 2020
# Processing 147/237: WMT 2020
# Processing 148/237: EACL 2021
# Processing 149/237: AAMAS 2023
# Processing 150/237: SDM 2021
# Processing 151/237: AISTATS 2021
# Processing 152/237: ICME 2021
# Processing 153/237: ICIP 2023
# Processing 154/237: MIDL 2021
# Processing 155/237: UAI 2021
# Processing 156/237: IROS 2021
# Processing 157/237: RSS 2021
# Processing 158/237: MICCAI 2023
# Processing 159/237: ICCV 2023
# Processing 160/237: ECML-PKDD 2021
# Processing 161/237: InterSpeech 2023
# Processing 162/237: FG 2021
# Processing 163/237: RecSys 2022
# Processing 164/237: EMNLP 2021
# Processing 165/237: CIKM 2021
# Processing 166/237: NeurIPS 2021
# Processing 167/237: WACV 2023
# Processing 168/237: ICDM 2021
# Processing 169/237: CoRL 2021
# Processing 170/237: AKBC 2021
# Processing 171/237: BMVC 2023
# Processing 172/237: ACML 2021
# Processing 173/237: WSDM 2022
# Processing 174/237: AAAI 2022
# Processing 175/237: ICRA 2023
# Processing 176/237: ICLR 2022
# Processing 177/237: ICASSP 2023
# Processing 178/237: AISTATS 2022
# Processing 179/237: WWW 2023
# Processing 180/237: ACL 2022
# Processing 181/237: CVPR 2023
# Processing 182/237: L4DC 2022
# Processing 183/237: ICAPS 2022
# Processing 184/237: LREC 2022
# Processing 185/237: IJCAI-ECAI 2022
# Processing 186/237: FAccT 2022
# Processing 187/237: CHIL 2023
# Processing 188/237: NAACL 2022
# Processing 189/237: ICWSM 2022
# Processing 190/237: ICML 2022
# Processing 191/237: SIGIR 2022
# Processing 192/237: RSS 2022
# Processing 193/237: KDD 2023
# Processing 194/237: ICIP 2022
# Processing 195/237: UAI 2022
# Processing 196/237: IROS 2022
# Processing 197/237: AutoML-Conf 2022
# Processing 198/237: CoLLAs 2022
# Processing 199/237: ECCV 2022
# Processing 200/237: RO-MAN 2022
# Processing 201/237: InterSpeech 2022
# Processing 202/237: ECML/PKDD 2022
# Processing 203/237: ISMIS 2022
# Processing 204/237: SIGGRAPH Asia 2022
# Processing 205/237: evoMUSART 2023
# Processing 206/237: LOG 2022
# Processing 207/237: AI4science NASSMA 2022 2022
# Processing 208/237: SIGGRAPH 2023
# Processing 209/237: ICDM 2023
# Processing 210/237: ECML/PKDD 2023
# Processing 211/237: ISWC 2023
# Processing 212/237: CIKM 2023
# Processing 213/237: AI World Barcelona 2023
# Processing 214/237: SPECOM 2024
# Processing 215/237: MIPR 2024
# Processing 216/237: AIware 2024
# Processing 217/237: AutoML 2024
# Processing 218/237: HIMSS Global Health Conference & Exhibition
# Processing 219/237: AMIA Annual Symposium
# Processing 220/237: AMIA Clinical Informatics Conference (CIC)
# Processing 221/237: HLTH (US & Europe)
# Processing 222/237: ViVE
# Processing 223/237: MEDICA
# Processing 224/237: World Health Expo (WHX)
# Processing 225/237: International Conference on Medical and Health Informatics (ICMHI)
# Processing 226/237: Connected Health Conference
# Processing 227/237: Digital Healthcare Innovation Summit
# Processing 228/237: Cancer Informatics for Cancer Centers Fall Symposium
# Processing 229/237: International Conference on Health Informatics, Intelligent Systems and Networking Technologies (HINT)
# Processing 230/237: Healthcare Information and Management Systems Society (HIMSS) Europe
# Processing 231/237: Health Sciences, Systems and Technologies (HSST)
# Processing 232/237: International Symposium on Medical Decision Science (ISMDS)
# Processing 233/237: Virginia HIMSS Annual Fall Conference
# Processing 234/237: GNUHealth Con
# Processing 235/237: AIMed Global Summit
# Processing 236/237: International Conference on Nursing and Healthcare
# Processing 237/237: Healthcare Summit London

# %%
df.to_csv("With_Keywords.csv",index = False)
