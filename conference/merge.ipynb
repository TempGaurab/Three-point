# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("cybersecurity_conferences.csv")
df
# Out:
#                                              Title  \
# 0     2025 PCI SSC North America Community Meeting
# 1            2025 PCI SSC Europe Community Meeting
# 2      2025 PCI SSC Asia-Pacific Community Meeting
# 3                              RSA Conference 2025
# 4                    Innovate Cybersecurity Summit
# 5                                         SAINTCON
# 6                      Cloud & Cyber Security Expo
# 7                                            HIMSS
# 8                                     HIMSS Europe
# 9                                            WiCyS
# 10       Gartner Security & Risk Management Summit
# 11                  ISACA North America Conference
# 12                             GRC Conference 2025
# 13                         ISACA Europe Conference
# 14                            The Diana Initiative
# 15                       Apres-Cyber Slopes Summit
# 16                                         DEF CON
# ...

# %%
df = df [['Title' , 'Link']]
df
# Out:
#                                              Title  \
# 0     2025 PCI SSC North America Community Meeting
# 1            2025 PCI SSC Europe Community Meeting
# 2      2025 PCI SSC Asia-Pacific Community Meeting
# 3                              RSA Conference 2025
# 4                    Innovate Cybersecurity Summit
# 5                                         SAINTCON
# 6                      Cloud & Cyber Security Expo
# 7                                            HIMSS
# 8                                     HIMSS Europe
# 9                                            WiCyS
# 10       Gartner Security & Risk Management Summit
# 11                  ISACA North America Conference
# 12                             GRC Conference 2025
# 13                         ISACA Europe Conference
# 14                            The Diana Initiative
# 15                       Apres-Cyber Slopes Summit
# 16                                         DEF CON
# ...

# %%
df['Type'] = 'CyberSecurity'
df
# Out:
#                                              Title  \
# 0     2025 PCI SSC North America Community Meeting
# 1            2025 PCI SSC Europe Community Meeting
# 2      2025 PCI SSC Asia-Pacific Community Meeting
# 3                              RSA Conference 2025
# 4                    Innovate Cybersecurity Summit
# 5                                         SAINTCON
# 6                      Cloud & Cyber Security Expo
# 7                                            HIMSS
# 8                                     HIMSS Europe
# 9                                            WiCyS
# 10       Gartner Security & Risk Management Summit
# 11                  ISACA North America Conference
# 12                             GRC Conference 2025
# 13                         ISACA Europe Conference
# 14                            The Diana Initiative
# 15                       Apres-Cyber Slopes Summit
# 16                                         DEF CON
# ...

# %%
df_hi = pd.read_csv("Health-informatics_conferences.csv")
df_hi
# Out:
#                                       Conference Name  \
# 0         HIMSS Global Health Conference & Exhibition
# 1                               AMIA Annual Symposium
# 2          AMIA Clinical Informatics Conference (CIC)
# 3                                  HLTH (US & Europe)
# 4                                                ViVE
# 5                                              MEDICA
# 6                             World Health Expo (WHX)
# 7   International Conference on Medical and Health...
# 8                         Connected Health Conference
# 9                Digital Healthcare Innovation Summit
# 10  Cancer Informatics for Cancer Centers Fall Sym...
# 11  International Conference on Health Informatics...
# 12  Healthcare Information and Management Systems ...
# 13   Health Sciences, Systems and Technologies (HSST)
# 14  International Symposium on Medical Decision Sc...
# 15              Virginia HIMSS Annual Fall Conference
# ...

# %%
df_hi['Title']  = df_hi['Conference Name']
df_hi['Type'] = 'Health Informatics'
df_hi = df_hi.drop(columns = ['Conference Name'])
df_hi
# Out:
#                                                  Link  \
# 0             https://www.himss.org/global-conference
# 1   https://amia.org/education-events/amia-annual-...
# 2   https://amia.org/education-events/amia-2025-cl...
# 3                                    https://hlth.com
# 4                           https://www.viveevent.com
# 5                    https://www.medica-tradefair.com
# 6                     https://www.worldhealthexpo.com
# 7                                   https://icmhi.org
# 8                 https://www.connectedhealthconf.org
# 9                                    https://dhis.net
# 10  https://www.cancer.gov/about-nci/organization/...
# 11                           https://hint.manipal.edu
# 12           https://www.himss.org/event-himss-europe
# 13                     https://www.hsstconference.org
# 14                                  https://ismds.org
# 15                            https://www.vahimss.org
# ...

# %%
df_aiml = pd.read_csv("extracted_AI_ML_conferences.csv")
df_aiml
# Out:
#                        Title              Short Name  \
# 0               AISTATS 2025             AISTATS '25
# 1                  CVPR 2025                CVPR '25
# 2                 NAACL 2025               NAACL '25
# 3                  ICLR 2025                ICLR '25
# 4                   LoG 2024                 LoG '24
# ..                       ...                     ...
# 187  AI World Barcelona 2023  AI World Barcelona '23
# 188              SPECOM 2024              SPECOM '24
# 189                MIPR 2024                MIPR '24
# 190              AIware 2024              AIware '24
# 191              AutoML 2024              AutoML '24
#
#                                      Conference URL  \
# 0        https://aistats.org/aistats2025/index.html
# 1          https://cvpr.thecvf.com/Conferences/2025
# 2                            https://2025.naacl.org
# 3    https://iclr.cc/Conferences/2025/CallForPapers
# 4                         https://logconference.org
# ...

# %%
df_aiml = df_aiml[['Title' , 'Conference URL']]
df_aiml
# Out:
#                        Title                                  Conference URL
# 0               AISTATS 2025      https://aistats.org/aistats2025/index.html
# 1                  CVPR 2025        https://cvpr.thecvf.com/Conferences/2025
# 2                 NAACL 2025                          https://2025.naacl.org
# 3                  ICLR 2025  https://iclr.cc/Conferences/2025/CallForPapers
# 4                   LoG 2024                       https://logconference.org
# ..                       ...                                             ...
# 187  AI World Barcelona 2023                  https://ai-world-barcelona.com
# 188              SPECOM 2024                https://specom2024.ftn.uns.ac.rs
# 189                MIPR 2024          https://sites.google.com/view/mipr2024
# 190              AIware 2024                   https://2024.aiwareconf.org/#
# 191              AutoML 2024                         https://2024.automl.cc/
#
# [192 rows x 2 columns]

# %%
df_aiml['Type'] = 'AI-ML'
# Out:
# C:\Users\gauur\AppData\Local\Temp\ipykernel_27956\3223047146.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aiml['Type'] = 'AI-ML'

# %%
df_aiml
# Out:
#                        Title                                  Conference URL  \
# 0               AISTATS 2025      https://aistats.org/aistats2025/index.html
# 1                  CVPR 2025        https://cvpr.thecvf.com/Conferences/2025
# 2                 NAACL 2025                          https://2025.naacl.org
# 3                  ICLR 2025  https://iclr.cc/Conferences/2025/CallForPapers
# 4                   LoG 2024                       https://logconference.org
# ..                       ...                                             ...
# 187  AI World Barcelona 2023                  https://ai-world-barcelona.com
# 188              SPECOM 2024                https://specom2024.ftn.uns.ac.rs
# 189                MIPR 2024          https://sites.google.com/view/mipr2024
# 190              AIware 2024                   https://2024.aiwareconf.org/#
# 191              AutoML 2024                         https://2024.automl.cc/
#
#       Type
# 0    AI-ML
# 1    AI-ML
# ...

# %%
df_aiml['Link']  = df_aiml['Conference URL']
# Out:
# C:\Users\gauur\AppData\Local\Temp\ipykernel_27956\1335630620.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aiml['Link']  = df_aiml['Conference URL']

# %%
df_aiml = df_aiml.drop(columns = ['Conference URL'])
df_aiml
# Out:
#                        Title   Type  \
# 0               AISTATS 2025  AI-ML
# 1                  CVPR 2025  AI-ML
# 2                 NAACL 2025  AI-ML
# 3                  ICLR 2025  AI-ML
# 4                   LoG 2024  AI-ML
# ..                       ...    ...
# 187  AI World Barcelona 2023  AI-ML
# 188              SPECOM 2024  AI-ML
# 189                MIPR 2024  AI-ML
# 190              AIware 2024  AI-ML
# 191              AutoML 2024  AI-ML
#
#                                                Link
# 0        https://aistats.org/aistats2025/index.html
# 1          https://cvpr.thecvf.com/Conferences/2025
# 2                            https://2025.naacl.org
# 3    https://iclr.cc/Conferences/2025/CallForPapers
# 4                         https://logconference.org
# ..                                              ...
# 187                  https://ai-world-barcelona.com
# 188                https://specom2024.ftn.uns.ac.rs
# ...

# %%
df_aiml
# Out:
#                        Title   Type  \
# 0               AISTATS 2025  AI-ML
# 1                  CVPR 2025  AI-ML
# 2                 NAACL 2025  AI-ML
# 3                  ICLR 2025  AI-ML
# 4                   LoG 2024  AI-ML
# ..                       ...    ...
# 187  AI World Barcelona 2023  AI-ML
# 188              SPECOM 2024  AI-ML
# 189                MIPR 2024  AI-ML
# 190              AIware 2024  AI-ML
# 191              AutoML 2024  AI-ML
#
#                                                Link
# 0        https://aistats.org/aistats2025/index.html
# 1          https://cvpr.thecvf.com/Conferences/2025
# 2                            https://2025.naacl.org
# 3    https://iclr.cc/Conferences/2025/CallForPapers
# 4                         https://logconference.org
# ..                                              ...
# 187                  https://ai-world-barcelona.com
# 188                https://specom2024.ftn.uns.ac.rs
# ...

# %%
df
# Out:
#                                              Title  \
# 0     2025 PCI SSC North America Community Meeting
# 1            2025 PCI SSC Europe Community Meeting
# 2      2025 PCI SSC Asia-Pacific Community Meeting
# 3                              RSA Conference 2025
# 4                    Innovate Cybersecurity Summit
# 5                                         SAINTCON
# 6                      Cloud & Cyber Security Expo
# 7                                            HIMSS
# 8                                     HIMSS Europe
# 9                                            WiCyS
# 10       Gartner Security & Risk Management Summit
# 11                  ISACA North America Conference
# 12                             GRC Conference 2025
# 13                         ISACA Europe Conference
# 14                            The Diana Initiative
# 15                       Apres-Cyber Slopes Summit
# 16                                         DEF CON
# ...

# %%
df
# Out:
#                                              Title  \
# 0     2025 PCI SSC North America Community Meeting
# 1            2025 PCI SSC Europe Community Meeting
# 2      2025 PCI SSC Asia-Pacific Community Meeting
# 3                              RSA Conference 2025
# 4                    Innovate Cybersecurity Summit
# 5                                         SAINTCON
# 6                      Cloud & Cyber Security Expo
# 7                                            HIMSS
# 8                                     HIMSS Europe
# 9                                            WiCyS
# 10       Gartner Security & Risk Management Summit
# 11                  ISACA North America Conference
# 12                             GRC Conference 2025
# 13                         ISACA Europe Conference
# 14                            The Diana Initiative
# 15                       Apres-Cyber Slopes Summit
# 16                                         DEF CON
# ...

# %%
df_new = pd.concat([df, df_aiml, df_hi])
df_new
# Out:
#                                                 Title  \
# 0        2025 PCI SSC North America Community Meeting
# 1               2025 PCI SSC Europe Community Meeting
# 2         2025 PCI SSC Asia-Pacific Community Meeting
# 3                                 RSA Conference 2025
# 4                       Innovate Cybersecurity Summit
# ..                                                ...
# 15              Virginia HIMSS Annual Fall Conference
# 16                                      GNUHealth Con
# 17                                AIMed Global Summit
# 18  International Conference on Nursing and Health...
# 19                           Healthcare Summit London
#
#                                                  Link                Type
# 0           https://events.pcisecuritystandards.org/#       CyberSecurity
# 1           https://events.pcisecuritystandards.org/#       CyberSecurity
# 2           https://events.pcisecuritystandards.org/#       CyberSecurity
# ...

# %%
df_new.Type.value_counts()
# Out:
# Type
# AI-ML                 192
# CyberSecurity          25
# Health Informatics     20
# Name: count, dtype: int64

# %%
df_new.to_csv("Links_for_all_conferences.csv", index = False)
