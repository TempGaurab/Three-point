# %%
import pandas as pd
from collections import Counter
import re

# %%
df = pd.read_csv("conference/extracted_AI_ML_conferences.csv")
df
# Out:
#                        Title              Short Name  \
# 0               AISTATS 2025             AISTATS '25
# 1                  CVPR 2025                CVPR '25
# 2                 NAACL 2025               NAACL '25
# 3                  ICLR 2025                ICLR '25
# 4                   LoG 2024                 LoG '24
# ..                       ...                     ...
# 187  AI World Barcelona 2023  AI World Barcelona '23
# 188              SPECOM 2024              SPECOM '24
# 189                MIPR 2024                MIPR '24
# 190              AIware 2024              AIware '24
# 191              AutoML 2024              AutoML '24
#
#                                      Conference URL  \
# 0        https://aistats.org/aistats2025/index.html
# 1          https://cvpr.thecvf.com/Conferences/2025
# 2                            https://2025.naacl.org
# 3    https://iclr.cc/Conferences/2025/CallForPapers
# 4                         https://logconference.org
# ...

# %%
#need deepseek agent and selenium to scrape this

# %%
df['Conference URL'].iloc[63]
# Out:
# 'http://2024.ieee-icra.org/'
