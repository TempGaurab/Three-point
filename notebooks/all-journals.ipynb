# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

data = [
    # AI-ML Journals
    {"Journal": "IEEE Transactions on Neural Networks and Learning Systems", "Link": "https://cis.ieee.org/publications/t-neural-networks-and-learning-systems", "Field": "AI/ML"},
    {"Journal": "IEEE Transactions on Pattern Analysis and Machine Intelligence", "Link": "https://www.computer.org/csdl/journal/tp", "Field": "AI/ML"},
    {"Journal": "Journal of Machine Learning Research", "Link": "https://www.jmlr.org/", "Field": "AI/ML"},
    {"Journal": "Nature Machine Intelligence", "Link": "https://www.nature.com/natmachintell/", "Field": "AI/ML"},
    {"Journal": "Journal of Artificial Intelligence Research (JAIR)", "Link": "https://jair.org/index.php/jair", "Field": "AI/ML"},
    {"Journal": "International Journal of Computer Vision", "Link": "https://www.springer.com/journal/11263", "Field": "AI/ML"},
    {"Journal": "Pattern Recognition", "Link": "https://www.journals.elsevier.com/pattern-recognition", "Field": "AI/ML"},
    {"Journal": "Expert Systems with Applications", "Link": "https://www.journals.elsevier.com/expert-systems-with-applications", "Field": "AI/ML"},
    {"Journal": "Neurocomputing", "Link": "https://www.journals.elsevier.com/neurocomputing", "Field": "AI/ML"},
    {"Journal": "Knowledge-Based Systems", "Link": "https://www.journals.elsevier.com/knowledge-based-systems", "Field": "AI/ML"},
    {"Journal": "Neural Networks", "Link": "https://www.journals.elsevier.com/neural-networks", "Field": "AI/ML"},
    {"Journal": "Applied Soft Computing", "Link": "https://www.journals.elsevier.com/applied-soft-computing", "Field": "AI/ML"},
    {"Journal": "Artificial Intelligence Review", "Link": "https://www.springer.com/journal/10462", "Field": "AI/ML"},
    {"Journal": "ACM Transactions on Intelligent Systems and Technology", "Link": "https://dl.acm.org/journal/tist", "Field": "AI/ML"},
    {"Journal": "Foundations and Trends in Machine Learning", "Link": "https://www.nowpublishers.com/mal", "Field": "AI/ML"},
    {"Journal": "Science Robotics", "Link": "https://www.science.org/journal/scirobotics", "Field": "AI/ML"},
    {"Journal": "IEEE Computational Intelligence Magazine", "Link": "https://cis.ieee.org/publications/ci-magazine", "Field": "AI/ML"},

    # Cybersecurity Journals
    {"Journal": "IEEE Transactions on Information Forensics and Security", "Link": "https://www.signalprocessingsociety.org/publications-resources/ieee-transactions-information-forensics-and-security", "Field": "Cybersecurity"},
    {"Journal": "ACM Transactions on Privacy and Security", "Link": "https://dl.acm.org/journal/tops", "Field": "Cybersecurity"},
    {"Journal": "Journal of Cybersecurity", "Link": "https://academic.oup.com/cybersecurity", "Field": "Cybersecurity"},
    {"Journal": "Computers & Security", "Link": "https://www.journals.elsevier.com/computers-and-security", "Field": "Cybersecurity"},
    {"Journal": "IEEE Security & Privacy", "Link": "https://www.computer.org/csdl/magazine/sp", "Field": "Cybersecurity"},

    # Health Informatics Journals
    {"Journal": "Journal of Biomedical Informatics", "Link": "https://www.journals.elsevier.com/journal-of-biomedical-informatics", "Field": "Health Informatics"},
    {"Journal": "Journal of the American Medical Informatics Association (JAMIA)", "Link": "https://academic.oup.com/jamia", "Field": "Health Informatics"},
    {"Journal": "International Journal of Medical Informatics", "Link": "https://www.journals.elsevier.com/international-journal-of-medical-informatics", "Field": "Health Informatics"},
    {"Journal": "IEEE Journal of Biomedical and Health Informatics", "Link": "https://jbhi.embs.org/", "Field": "Health Informatics"},
    {"Journal": "BMC Medical Informatics and Decision Making", "Link": "https://bmcmedinformdecismak.biomedcentral.com/", "Field": "Health Informatics"},
    {"Journal": "Methods of Information in Medicine", "Link": "https://www.thieme.de/de/methods-information-medicine/journal-information-121222.htm", "Field": "Health Informatics"},
]

df = pd.DataFrame(data)
df
# Out:
#                                               Journal  \
# 0   IEEE Transactions on Neural Networks and Learn...
# 1   IEEE Transactions on Pattern Analysis and Mach...
# 2                Journal of Machine Learning Research
# 3                         Nature Machine Intelligence
# 4   Journal of Artificial Intelligence Research (J...
# 5            International Journal of Computer Vision
# 6                                 Pattern Recognition
# 7                    Expert Systems with Applications
# 8                                      Neurocomputing
# 9                             Knowledge-Based Systems
# 10                                    Neural Networks
# 11                             Applied Soft Computing
# 12                     Artificial Intelligence Review
# 13  ACM Transactions on Intelligent Systems and Te...
# 14         Foundations and Trends in Machine Learning
# 15                                   Science Robotics
# ...

# %%
for data in df.Link:
    print(data)
# Out:
# https://cis.ieee.org/publications/t-neural-networks-and-learning-systems
# https://www.computer.org/csdl/journal/tp
# https://www.jmlr.org/
# https://www.nature.com/natmachintell/
# https://jair.org/index.php/jair
# https://www.springer.com/journal/11263
# https://www.journals.elsevier.com/pattern-recognition
# https://www.journals.elsevier.com/expert-systems-with-applications
# https://www.journals.elsevier.com/neurocomputing
# https://www.journals.elsevier.com/knowledge-based-systems
# https://www.journals.elsevier.com/neural-networks
# https://www.journals.elsevier.com/applied-soft-computing
# https://www.springer.com/journal/10462
# https://dl.acm.org/journal/tist
# https://www.nowpublishers.com/mal
# https://www.science.org/journal/scirobotics
# https://cis.ieee.org/publications/ci-magazine
# https://www.signalprocessingsociety.org/publications-resources/ieee-transactions-information-forensics-and-security
# https://dl.acm.org/journal/tops
# ...

# %%
df.to_csv("Top-journals.csv",index = False)
