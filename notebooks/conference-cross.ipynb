# %%
import pandas as pd
data = {
    "Conference Name": [
        "HIMSS 2025 Global Health Conference & Exhibition",
        "AMIA 2025 Clinical Informatics Conference",
        "AI Cybersecurity Summit 2025 (SANS Institute)",
        "Healthcare Innovation Summit 2025",
        "Cybertech USA 2025",
        "Innovate Cybersecurity Summit – Nashville 2025",
        "46th IEEE Symposium on Security and Privacy",
        "Black Hat USA 2025",
        "Digital Health 2025",
        "DMEA 2025: Next Level of Digital Health"
    ],
    "Link": [
        "https://www.himss.org/global-conference",
        "https://amia.org/education-events/amia-2025-clinical-informatics-conference/call-participation",
        "https://www.sans.org/cyber-security-training-events/ai-summit-2025/",
        "https://infosec-conferences.com/event-series/healthcare-innovation-summit/",
        "https://usa.cybertechconference.com/",
        "https://innovatecybersecurity.com/nashville/",
        "https://www.ieee-security.org/TC/SP2025/",
        "https://www.blackhat.com/us-25/",
        "https://www.digitalhealth2025.com/",
        "https://www.dmea.de/en/"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                                     Conference Name  \
# 0  HIMSS 2025 Global Health Conference & Exhibition
# 1         AMIA 2025 Clinical Informatics Conference
# 2     AI Cybersecurity Summit 2025 (SANS Institute)
# 3                 Healthcare Innovation Summit 2025
# 4                                Cybertech USA 2025
# 5    Innovate Cybersecurity Summit – Nashville 2025
# 6       46th IEEE Symposium on Security and Privacy
# 7                                Black Hat USA 2025
# 8                               Digital Health 2025
# 9           DMEA 2025: Next Level of Digital Health
#
#                                                 Link
# 0            https://www.himss.org/global-conference
# 1  https://amia.org/education-events/amia-2025-cl...
# 2  https://www.sans.org/cyber-security-training-e...
# 3  https://infosec-conferences.com/event-series/h...
# 4               https://usa.cybertechconference.com/
# 5       https://innovatecybersecurity.com/nashville/
# ...

# %%
df.to_csv("Potential_conference_cross.csv", index = False)
